# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy

print(tweepy.__version__)
# Out:
# 4.13.0

# %%
import tweepy
import csv
from datetime import datetime, timedelta

# Set up Twitter API credentials
consumer_key = 'tuopEJa4I562s5QRtCfTiZnrI'
consumer_secret = 'tGD8leV9o7aGTE5dEXx77jm8TF5W8vYMLBKRZDbz6bcjqbDIz8'
access_token = '1231985298751590404-iIWijICrpkjTijmE1wn9818axnEBl1'
access_secret = 'Bsj5d241AFWw8n8MTprWqVSnB7m1OTDOfwP3iYTDNHuZ8'

# Authenticate Twitter API credentials
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret,
    access_token, access_secret,
    wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True
)
api = tweepy.API(auth)

# Set search query, start date, and end date
query = 'YOUR_SEARCH_QUERY'
start_date = datetime(2023, 5, 1, 0, 0, 0)
end_date = datetime(2023, 5, 14, 23, 59, 59)

# Open a CSV file to write the results to
with open('tweets.csv', 'w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["created_at", "text"])

    # Collect tweets using Tweepy API v1.1 search method
    for tweet in tweepy.Cursor(api.search_tweets,
                               q=query,
                               tweet_mode='extended',
                               lang='en',
                               since_id=None,
                               until=(end_date + timedelta(days=1)).strftime('%Y-%m-%d'),
                               since=start_date.strftime('%Y-%m-%d'),
                               count=100).items():

        # Check if the tweet is within the specified date range
        if tweet.created_at >= start_date and tweet.created_at <= end_date:

            # Write the tweet to the CSV file
            writer.writerow([tweet.created_at, tweet.full_text.encode('utf-8')])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6e71d0648be1> in <cell line: 12>()
#      10
#      11 # Authenticate Twitter API credentials
# ---> 12 auth = tweepy.OAuth1UserHandler(
#      13     consumer_key, consumer_secret,
#      14     access_token, access_secret,
#
# TypeError: OAuth1UserHandler.__init__() got an unexpected keyword argument 'wait_on_rate_limit'

# %%
import tweepy
import csv
from datetime import datetime, timedelta

# Set up Twitter API credentials
consumer_key = 'tuopEJa4I562s5QRtCfTiZnrI'
consumer_secret = 'tGD8leV9o7aGTE5dEXx77jm8TF5W8vYMLBKRZDbz6bcjqbDIz8'
access_token = '1231985298751590404-iIWijICrpkjTijmE1wn9818axnEBl1'
access_secret = 'Bsj5d241AFWw8n8MTprWqVSnB7m1OTDOfwP3iYTDNHuZ8'

# Authenticate Twitter API credentials
auth = tweepy.OAuth1Handler(consumer_key, consumer_secret, access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# Set search query, start date, and end date
query = 'YOUR_SEARCH_QUERY'
start_date = datetime(2023, 5, 1, 0, 0, 0)
end_date = datetime(2023, 5, 14, 23, 59, 59)

# Open a CSV file to write the results to
with open('tweets.csv', 'w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["created_at", "text"])

    # Collect tweets using Tweepy API v1.1 search method
    for tweet in tweepy.Cursor(api.search_tweets,
                               q=query,
                               tweet_mode='extended',
                               lang='en',
                               since_id=None,
                               until=(end_date + timedelta(days=1)).strftime('%Y-%m-%d'),
                               since=start_date.strftime('%Y-%m-%d'),
                               count=100).items():

        # Check if the tweet is within the specified date range
        if tweet.created_at >= start_date and tweet.created_at <= end_date:

            # Write the tweet to the CSV file
            writer.writerow([tweet.created_at, tweet.full_text.encode('utf-8')])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a31b036ab9ad> in <cell line: 12>()
#      10
#      11 # Authenticate Twitter API credentials
# ---> 12 auth = tweepy.OAuth1Handler(consumer_key, consumer_secret, access_token, access_secret)
#      13 api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
#      14
#
# AttributeError: module 'tweepy' has no attribute 'OAuth1Handler'
